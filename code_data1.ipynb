# %% [markdown]
# Importing Modules

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# Getting the data

# %%
data=pd.read_csv('data1.csv')
data.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   3       145   233    1        0      150      0      2.3      0
# 1   37    1   2       130   250    0        1      187      0      3.5      0
# 2   41    0   1       130   204    0        0      172      0      1.4      2
# 3   56    1   1       120   236    0        1      178      0      0.8      2
# 4   57    0   0       120   354    0        1      163      1      0.6      2
#
#    ca  thal  target
# 0   0     1       1
# 1   0     2       1
# 2   0     2       1
# 3   0     2       1
# 4   0     2       1

# %% [markdown]
# Data Analysis

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 303 entries, 0 to 302
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       303 non-null    int64
#  1   sex       303 non-null    int64
#  2   cp        303 non-null    int64
#  3   trestbps  303 non-null    int64
#  4   chol      303 non-null    int64
#  5   fbs       303 non-null    int64
#  6   restecg   303 non-null    int64
#  7   thalach   303 non-null    int64
#  8   exang     303 non-null    int64
#  9   oldpeak   303 non-null    float64
#  10  slope     303 non-null    int64
#  11  ca        303 non-null    int64
#  12  thal      303 non-null    int64
#  13  target    303 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 33.3 KB

# %%
data.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean    54.366337    0.683168    0.966997  131.623762  246.264026    0.148515
# std      9.082101    0.466011    1.032052   17.538143   51.830751    0.356198
# min     29.000000    0.000000    0.000000   94.000000  126.000000    0.000000
# 25%     47.500000    0.000000    0.000000  120.000000  211.000000    0.000000
# 50%     55.000000    1.000000    1.000000  130.000000  240.000000    0.000000
# 75%     61.000000    1.000000    2.000000  140.000000  274.500000    0.000000
# max     77.000000    1.000000    3.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang     oldpeak       slope          ca  \
# count  303.000000  303.000000  303.000000  303.000000  303.000000  303.000000
# mean     0.528053  149.646865    0.326733    1.039604    1.399340    0.729373
# ...

# %%
data.corr()
# Out:
#                age       sex        cp  trestbps      chol       fbs  \
# age       1.000000 -0.098447 -0.068653  0.279351  0.213678  0.121308
# sex      -0.098447  1.000000 -0.049353 -0.056769 -0.197912  0.045032
# cp       -0.068653 -0.049353  1.000000  0.047608 -0.076904  0.094444
# trestbps  0.279351 -0.056769  0.047608  1.000000  0.123174  0.177531
# chol      0.213678 -0.197912 -0.076904  0.123174  1.000000  0.013294
# fbs       0.121308  0.045032  0.094444  0.177531  0.013294  1.000000
# restecg  -0.116211 -0.058196  0.044421 -0.114103 -0.151040 -0.084189
# thalach  -0.398522 -0.044020  0.295762 -0.046698 -0.009940 -0.008567
# exang     0.096801  0.141664 -0.394280  0.067616  0.067023  0.025665
# oldpeak   0.210013  0.096093 -0.149230  0.193216  0.053952  0.005747
# slope    -0.168814 -0.030711  0.119717 -0.121475 -0.004038 -0.059894
# ca        0.276326  0.118261 -0.181053  0.101389  0.070511  0.137979
# thal      0.068001  0.210041 -0.161736  0.062210  0.098803 -0.032019
# ...

# %%
for i in data.columns.to_list():
    plt.figure(figsize=(6, 4))
    colors = ['red' if is_true else 'blue' for is_true in data['target']]
    plt.scatter(range(len(data[i])), data[i], color=colors, s=50)
    plt.title(i)
    plt.xlabel("Index")
    plt.ylabel(i)
    plt.show()

# %% [markdown]
# ### Trying different feature selection techniques

# %%
data.drop_duplicates(inplace=True)

# %%
y=data['target']
x=data.drop(['target'],axis=1)

# %% [markdown]
# # PCA

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix

scaler = StandardScaler()
scaled_x = scaler.fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(scaled_x, y, test_size=0.2, random_state=42)

components_range = range(1, x.shape[1] + 1)
accuracies = []
falsenegatives=[]

for n_components in components_range:
    pca = PCA(n_components=n_components)
    x_train_pca = pca.fit_transform(x_train)
    x_test_pca = pca.transform(x_test)
    
    model = RandomForestClassifier(random_state=42)
    model.fit(x_train_pca, y_train)
    
    y_pred = model.predict(x_test_pca)
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)
    cm = confusion_matrix(y_test, y_pred)
    fn = cm[1, 0]
    falsenegatives.append(fn)


plt.figure(figsize=(8, 5))
plt.plot(components_range, accuracies, marker='o', linestyle='-', color='b')
plt.title('PCA Components vs Accuracy')
plt.xlabel('Number of PCA Components')
plt.ylabel('Accuracy')
plt.grid()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(components_range, falsenegatives, marker='o', linestyle='-', color='red')
plt.title('PCA Components vs False Negatives')
plt.xlabel('Number of PCA Components')
plt.ylabel('False Negatives')
plt.grid()
plt.show()

# %% [markdown]
# ## SMOTE + PCA

# %%
from imblearn.over_sampling import SMOTE

components_range = range(1, x.shape[1] + 1)
accuracies = []
falsenegatives=[]

smote = SMOTE(random_state=42,sampling_strategy=1.0)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

for n_components in components_range:
    pca = PCA(n_components=n_components)
    x_train_pca = pca.fit_transform(x_train_balanced)
    x_test_pca = pca.transform(x_test)
    
    model = RandomForestClassifier(random_state=42)
    model.fit(x_train_pca, y_train_balanced)
    
    y_pred = model.predict(x_test_pca)
    acc = accuracy_score(y_test, y_pred)
    accuracies.append(acc)
    cm = confusion_matrix(y_test, y_pred)
    fn = cm[1, 0]
    falsenegatives.append(fn)


plt.figure(figsize=(8, 5))
plt.plot(components_range, accuracies, marker='o', linestyle='-', color='b')
plt.title('PCA Components vs Accuracy')
plt.xlabel('Number of PCA Components')
plt.ylabel('Accuracy')
plt.grid()
plt.show()

plt.figure(figsize=(8, 5))
plt.plot(components_range, falsenegatives, marker='o', linestyle='-', color='red')
plt.title('PCA Components vs False Negatives')
plt.xlabel('Number of PCA Components')
plt.ylabel('False Negatives')
plt.grid()
plt.show()

# %% [markdown]
# #### SMOTE decreases the accuracy

# %% [markdown]
# ### BERUTA

# %%
from boruta import BorutaPy

x_train = pd.DataFrame(x_train, columns=x.columns)
x_test = pd.DataFrame(x_test, columns=x.columns)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
boruta = BorutaPy(estimator=rf, n_estimators='auto', random_state=42)

boruta.fit(x_train, y_train)

selected_features = x_train.columns[boruta.support_].tolist()
print("Selected Features:", selected_features)

ranking = boruta.ranking_
print("Feature Ranking:", ranking)
x_train_selected = boruta.transform(x_train.values)
x_test_selected = boruta.transform(x_test.values)
# Out:
# Selected Features: ['age', 'cp', 'thalach', 'oldpeak', 'ca', 'thal']
# Feature Ranking: [1 6 1 3 4 8 7 1 2 1 5 1 1]

# %% [markdown]
# #### BERUTA giving same results as randomforest feature importance

# %% [markdown]
# ### BERUTA + SMOTE

# %%
from boruta import BorutaPy
from imblearn.over_sampling import SMOTE

smote = SMOTE(random_state=42,sampling_strategy = 1.0)
x_train_balanced, y_train_balanced = smote.fit_resample(x_train, y_train)

x_train_balanced = pd.DataFrame(x_train_balanced, columns=x.columns)
x_test = pd.DataFrame(x_test, columns=x.columns)

rf = RandomForestClassifier(n_estimators=100, random_state=42)
boruta = BorutaPy(estimator=rf, n_estimators='auto', random_state=42)

boruta.fit(x_train_balanced, y_train_balanced)

selected_features = x_train_balanced.columns[boruta.support_].tolist()
print("Selected Features:", selected_features)

ranking = boruta.ranking_
print("Feature Ranking:", ranking)
x_train_selected = boruta.transform(x_train_balanced.values)
x_test_selected = boruta.transform(x_test.values)
# Out:
# Selected Features: ['age', 'cp', 'thalach', 'oldpeak', 'ca', 'thal']
# Feature Ranking: [1 6 1 2 4 8 7 1 3 1 5 1 1]

# %%
#feature importance method

from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

#for getting features
model = RandomForestClassifier(random_state=42)
model.fit(x_train, y_train)
importances = model.feature_importances_

important_features = pd.DataFrame({"Feature": x.columns,"Importance": importances}).sort_values(by="Importance", ascending=False)

print("Top Features Based on Importance:")
print(important_features)
# Out:
# Top Features Based on Importance:
#      Feature  Importance
# 12      thal    0.149040
# 7    thalach    0.127162
# 2         cp    0.122974
# 9    oldpeak    0.093371
# 11        ca    0.087495
# 0        age    0.085434
# 4       chol    0.077064
# 10     slope    0.067346
# 3   trestbps    0.061474
# 8      exang    0.061213
# 1        sex    0.039859
# 6    restecg    0.017163
# 5        fbs    0.010405

# %%
x_new=x[['oldpeak','thalach','ca','cp','thal','age']]
x_new.head()
# Out:
#    oldpeak  thalach  ca  cp  thal  age
# 0      2.3      150   0   3     1   63
# 1      3.5      187   0   2     2   37
# 2      1.4      172   0   1     2   41
# 3      0.8      178   0   1     2   56
# 4      0.6      163   0   0     2   57

# %% [markdown]
# ### n-components selected - 5 (Without SMOTE)

# %%
scaler = StandardScaler()
scaled_x = scaler.fit_transform(x)

x_train, x_test, y_train, y_test = train_test_split(scaled_x, y, test_size=0.2, random_state=42)


pca = PCA(n_components=5)
x_train_pca_f = pca.fit_transform(x_train)
x_test_pca_f = pca.transform(x_test)

# %% [markdown]
# ## ->Selecting the model

# %% [markdown]
# ### 1) For PCA data

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier

test_model = [LogisticRegression(random_state =42),DecisionTreeClassifier(random_state =42),RandomForestClassifier(random_state =42), 
              ExtraTreesClassifier(random_state =42),GradientBoostingClassifier(random_state =42),AdaBoostClassifier(random_state =42),XGBClassifier(random_state=42)]
model = ['Logistic Regression','Decision Tree Classifier','Random Forest Classifier','ExtraTreesClassifier',
         'GradientBoostingClassifier','AdaBoostClassifier','XGB']
result = pd.DataFrame(columns=['Model','Accuracy','False_Negative'])
for i, j in enumerate(test_model):
    train_model = j.fit(x_train_pca_f,y_train)
    test_model = j.predict(x_test_pca_f)
    accuracy_scores = accuracy_score(y_test,test_model)
    cm = confusion_matrix(y_test, test_model)
    fn = cm[1, 0]
    
    results = pd.DataFrame({'Model':[model[i]],'Accuracy':[accuracy_scores],'False_negative':[fn]})
    result = pd.concat([result,results],ignore_index = True)
result
# Out:
#                         Model  Accuracy False_Negative  False_negative
# 0         Logistic Regression  0.868852            NaN             4.0
# 1    Decision Tree Classifier  0.704918            NaN            13.0
# 2    Random Forest Classifier  0.868852            NaN             4.0
# 3        ExtraTreesClassifier  0.819672            NaN             6.0
# 4  GradientBoostingClassifier  0.819672            NaN             6.0
# 5          AdaBoostClassifier  0.803279            NaN             6.0
# 6                         XGB  0.819672            NaN             5.0

# %% [markdown]
# ## Selected Models - XGB,logistic regression,Gradient boosting

# %% [markdown]
# ### Finding a good threshold to minimise false negatives

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix, make_scorer

model = LogisticRegression(random_state=42)
model.fit(x_train_pca_f,y_train)
y_pred_proba = model.predict_proba(x_test_pca_f)[:,1]
thresholds = np.linspace(0.1,0.6,20)
accuracies=[]
false_negatives=[]
for i in thresholds:
    y_pred = (y_pred_proba >= i).astype(int)
    accuracies.append(accuracy_score(y_test, y_pred))
    cm=confusion_matrix(y_test,y_pred)
    false_negatives.append(cm[1,0])

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(thresholds, accuracies, marker='o', color='blue', label='Accuracy')
plt.title('Accuracy vs. Threshold')
plt.xlabel('Threshold')
plt.ylabel('Accuracy')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(thresholds, false_negatives, marker='o', color='red', label='False Negatives')
plt.title('False Negatives vs. threshold')
plt.xlabel('threshold')
plt.ylabel('Number of False Negatives')
plt.grid(True)

plt.show()

# %% [markdown]
# ### selected threshold - 0.3

# %%
## XGBoost

model = XGBClassifier(use_label_encoder=False, eval_metric='logloss', random_state=42)

param_grid = {
    'n_estimators': [50, 100, 200],'learning_rate': [0.01, 0.1, 0.2],'max_depth': [3, 5, 7],                 
    'min_child_weight': [1, 3, 5],'gamma': [0, 0.1, 0.2],'subsample': [0.8, 1.0],                
    'colsample_bytree': [0.8, 1.0]}

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
                           scoring='recall', cv=5, verbose=1, n_jobs=-1)

grid_search.fit(x_train_pca_f, y_train)

best_model = grid_search.best_estimator_

y_pred_prob = best_model.predict_proba(x_test_pca_f)[:,1]
threshold = 0.3
y_pred = (y_pred_proba >= threshold).astype(int)

print("\nAccuracy on Test Data:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))

print("\nConfusion Matrix",confusion_matrix(y_test,y_pred))
# Out:
# Fitting 5 folds for each of 972 candidates, totalling 4860 fits
#
# Accuracy on Test Data: 0.8688524590163934
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86        29
#            1       0.85      0.91      0.88        32
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61
#
#
# Confusion Matrix [[24  5]
#  [ 3 29]]

# %%
#gradient boosting

from sklearn.ensemble import GradientBoostingClassifier

model = GradientBoostingClassifier(random_state=42)

param_grid = {
    'n_estimators': [50, 100, 200],'learning_rate': [0.01, 0.1, 0.2],'max_depth': [3, 4, 5],
    'min_samples_split': [2, 5, 10],'min_samples_leaf': [1, 2, 4],'subsample': [0.6, 0.8, 1.0]}

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
                           scoring='recall', cv=5, verbose=2, n_jobs=-1)
grid_search.fit(x_train_pca_f, y_train)

best_model = grid_search.best_estimator_

y_pred_prob = best_model.predict_proba(x_test_pca_f)[:,1]
threshold=0.3
y_pred = (y_pred_proba >= threshold).astype(int)
print("\nAccuracy on Test Data:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
print("\nConfusion Matrix:",confusion_matrix(y_test,y_pred))
# Out:
# Fitting 5 folds for each of 729 candidates, totalling 3645 fits
#
# Accuracy on Test Data: 0.8688524590163934
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.89      0.83      0.86        29
#            1       0.85      0.91      0.88        32
#
#     accuracy                           0.87        61
#    macro avg       0.87      0.87      0.87        61
# weighted avg       0.87      0.87      0.87        61
#
#
# Confusion Matrix: [[24  5]
#  [ 3 29]]

# %% [markdown]
# ## So, the best result is
# ### Accuracy : 0.87
# ### False Negatives : 3

# %%
## Now, lets do beruta and not PCA

# %%
x_new=x[['age', 'cp', 'thalach', 'oldpeak', 'ca', 'thal']]
scaler = StandardScaler()
scaled_x = scaler.fit_transform(x_new)
x_train, x_test, y_train, y_test = train_test_split(scaled_x, y, test_size=0.2, random_state=42)

# %%
from sklearn.metrics import confusion_matrix, accuracy_score, precision_score, recall_score, f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, ExtraTreesClassifier, GradientBoostingClassifier, AdaBoostClassifier
from xgboost import XGBClassifier

test_model = [LogisticRegression(random_state =42),DecisionTreeClassifier(random_state =42),RandomForestClassifier(random_state =42), 
              ExtraTreesClassifier(random_state =42),GradientBoostingClassifier(random_state =42),AdaBoostClassifier(random_state =42),XGBClassifier(random_state=42)]
model = ['Logistic Regression','Decision Tree Classifier','Random Forest Classifier','ExtraTreesClassifier',
         'GradientBoostingClassifier','AdaBoostClassifier','XGB']
result = pd.DataFrame(columns=['Model','Accuracy','False_Negative'])
for i, j in enumerate(test_model):
    train_model = j.fit(x_train,y_train)
    y_pred_proba = j.predict_proba(x_test)[:, 1]
    test_model = j.predict(x_test)
    accuracy_scores = accuracy_score(y_test,test_model)
    cm = confusion_matrix(y_test, test_model)
    fn = cm[1, 0]
    
    results = pd.DataFrame({'Model':[model[i]],'Accuracy':[accuracy_scores],'False_negative':[fn]})
    result = pd.concat([result,results],ignore_index = True)
result
# Out:
#                         Model  Accuracy False_Negative  False_negative
# 0         Logistic Regression  0.852459            NaN             3.0
# 1    Decision Tree Classifier  0.770492            NaN             9.0
# 2    Random Forest Classifier  0.868852            NaN             4.0
# 3        ExtraTreesClassifier  0.852459            NaN             5.0
# 4  GradientBoostingClassifier  0.852459            NaN             6.0
# 5          AdaBoostClassifier  0.786885            NaN             8.0
# 6                         XGB  0.852459            NaN             5.0

# %%
## Model Logistic , Random Forest

## Losgistic Regression
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import accuracy_score, classification_report
from sklearn.metrics import confusion_matrix, make_scorer

model = LogisticRegression(max_iter=1000, random_state=42)

grid_search = GridSearchCV(estimator=model, param_grid=param_grid, 
                           cv=5, scoring='accuracy', verbose=1, n_jobs=-1)

model.fit(x_train, y_train)
y_pred_prob = model.predict_proba(x_test)[:,1]
thresholds = np.linspace(0.1,0.6,20)
accuracies=[]
false_negatives=[]
for i in thresholds:
    y_pred = (y_pred_proba >= i).astype(int)
    accuracies.append(accuracy_score(y_test, y_pred))
    cm=confusion_matrix(y_test,y_pred)
    false_negatives.append(cm[1,0])

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(thresholds, accuracies, marker='o', color='blue', label='Accuracy')
plt.title('Accuracy vs. Threshold')
plt.xlabel('Threshold')
plt.ylabel('Accuracy')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(thresholds, false_negatives, marker='o', color='red', label='False Negatives')
plt.title('False Negatives vs. threshold')
plt.xlabel('threshold')
plt.ylabel('Number of False Negatives')
plt.grid(True)

plt.show()

# %% [markdown]
# ### So changing the threshold only decreases the accuracy

# %%
# Random forest 

from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV, train_test_split
from sklearn.metrics import recall_score, confusion_matrix

rf = RandomForestClassifier(random_state=42)

# Define the hyperparameter grid
param_grid = {
    'n_estimators': [50, 100, 200],          # Number of trees
    'max_depth': [None, 10, 20, 30],        # Maximum depth of trees
    'min_samples_split': [2, 5, 10],        # Minimum samples to split a node
    'min_samples_leaf': [1, 2, 4],          # Minimum samples at a leaf
    'max_features': ['sqrt', 'log2', None], # Features to consider for split
    'class_weight': [None, 'balanced', 'balanced_subsample']  # Class balancing
}

# Set up GridSearchCV
grid_search = GridSearchCV(estimator=rf, param_grid=param_grid, 
                           cv=5, scoring='recall', verbose=1, n_jobs=-1)

grid_search.fit(x_train, y_train)

best_model = grid_search.best_estimator_
y_pred = best_model.predict(x_test)

accuracy = accuracy_score(y_test, y_pred)
print("Test Accuracy:", accuracy)


cm = confusion_matrix(y_test, y_pred)
print("Confusion Matrix:\n", cm)
# Out:
# Fitting 5 folds for each of 972 candidates, totalling 4860 fits
# Test Accuracy: 0.8360655737704918
# Confusion Matrix:
#  [[24  5]
#  [ 5 27]]

# %%
y_pred_prob = best_model.predict_proba(x_test)[:,1]
thresholds = np.linspace(0.1,0.6,20)
accuracies=[]
false_negatives=[]
for i in thresholds:
    y_pred = (y_pred_proba >= i).astype(int)
    accuracies.append(accuracy_score(y_test, y_pred))
    cm=confusion_matrix(y_test,y_pred)
    false_negatives.append(cm[1,0])

plt.figure(figsize=(12, 6))
plt.subplot(1, 2, 1)
plt.plot(thresholds, accuracies, marker='o', color='blue', label='Accuracy')
plt.title('Accuracy vs. Threshold')
plt.xlabel('Threshold')
plt.ylabel('Accuracy')
plt.grid(True)

plt.subplot(1, 2, 2)
plt.plot(thresholds, false_negatives, marker='o', color='red', label='False Negatives')
plt.title('False Negatives vs. threshold')
plt.xlabel('threshold')
plt.ylabel('Number of False Negatives')
plt.grid(True)

plt.show()

# %%
# threshold 0.5 

y_pred = (y_pred_proba >= 0.5).astype(int)
print("Accuracy:",accuracy_score(y_test, y_pred))
print("Confusion Matrix:",confusion_matrix(y_test,y_pred))
# Out:
# Accuracy: 0.8524590163934426
# Confusion Matrix: [[25  4]
#  [ 5 27]]

# %% [markdown]
# ### So, Final result from BERUTA data :
# #### Accuracy : 0.85
# #### False Negative : 5

# %% [markdown]
# ## Final Summary of this data:
# #### Got best result after doing PCA (with n_components=5) and using model Gradient Boosting Classifier to get,
# #### Accuracy 0.87 | False Negative 3
